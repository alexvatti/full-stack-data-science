# %% [markdown]
# # MNIST Handwritten Digits Classification using Neural Network
#
# # Introduction
#
# The data files contain gray-scale images of hand-drawn digits, from zero through nine.
#
# Each image is 28 pixels in height and 28 pixels in width, for a total of 784 pixels in total. Each pixel has a single pixel-value associated with it, indicating the lightness or darkness of that pixel. This pixel-value is an integer between 0 and 255, inclusive.
#
# # Problem-Statement
# In this notebook we will classify handwritten digits using a simple neural network which has only input and output layers. We will than add a hidden layer and see how the performance of the model improves

# %% [markdown]
# ## ANN - NN

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Activation functions

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Loss/Cost functions

# %% [markdown]
# The purpose of loss functions is to compute the quantity that a model should seek to minimize during training.
#
#  1. binary_crossentropy function
#  2. categorical_crossentropy function
#  3. sparse_categorical_crossentropy function
#  4. mean_squared_error function
#  5. mean_absolute_error function
#  6. mean_absolute_percentage_error function
#  7. mean_squared_logarithmic_error function

# %% [markdown]
# ## Optimizers
#
# 1. SGD
# 2. RMSprop
# 3. Adam

# %% [markdown]
# # Sigmoid function - Derivative

# %%
import matplotlib.pyplot as plt
import numpy as np

def sigmoid(x):
    s=1/(1+np.exp(-x))
    ds=s*(1-s)  
    return s,ds
x=np.arange(-6,6,0.1)
#print(x)
#print(len(x))
#sigmoid(x)
# Create and show plot
fig, ax = plt.subplots(figsize=(6, 4))
plt.grid()
ax.plot(x,sigmoid(x)[0], color="blue", linewidth=3, label="sigmoid")
ax.plot(x,sigmoid(x)[1], color="red", linewidth=3, label="derivative")
ax.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Observations
# 1. Derivate values are in between 0 and 0.3
# 2. Derivate values become non zero , if sigmoid values are in range -4 to 4 , otherwise it is zero

# %% [markdown]
# # tanh or Hyperbolic function - Derivative

# %%
import matplotlib.pyplot as plt
import numpy as np

def tanh(x):
    t=(np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x))
    dt=1-t**2
    return t,dt

z=np.arange(-4,4,0.01)
# Create and show plot
fig, ax = plt.subplots(figsize=(6, 4))
plt.grid()
ax.plot(z,tanh(z)[0], color="blue", linewidth=3, label="tanh")
ax.plot(z,tanh(z)[1], color="red", linewidth=3, label="derivative")
ax.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Observations
# 1. Derivate values are in between 0 and 1
# 2. Derivate values become non zero , if tanh values are in range -3 to 3 , otherwise it is zero

# %% [markdown]
# # Vanishing gradient
# As more layers using certain activation functions are added to neural networks, the gradients of the loss function approaches zero, making the network hard to train.

# %% [markdown]
# # 1.Import Python modules

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
# Out:
# C:\Users\91956\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# WARNING:tensorflow:From C:\Users\91956\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # 2. Load Dataset - MNIST

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
(X_train, Y_train) , (X_test, Y_test) = keras.datasets.mnist.load_data()
print("train data length:",len(X_train))
print("test data length:",len(X_test))
# Out:
# train data length: 60000
# test data length: 10000

# %% [markdown]
# # 3. Scaling

# %%
from tensorflow.keras.utils import to_categorical
Y_train_saved = Y_train
Y_test_saved = Y_test
Y_train = to_categorical(Y_train, 10)
Y_test = to_categorical(Y_test, 10)
print(Y_train.shape)
print(Y_test.shape)
# Normalize the features
X_train = X_train / 255
X_test = X_test / 255

# reashaping the 784 pixels into 28 x 28 matrix which represents the pixels of the actual image
# as input we will have an array of these matrices
X_train_scaled = X_train.reshape(X_train.shape[0],28*28)
X_test_scaled = X_test.reshape(X_test.shape[0],28*28)
# Out:
# (60000, 10)
# (10000, 10)

# %% [markdown]
# # 4. Model

# %% [markdown]
# ## 4.1 Very simple neural network with no hidden layers- Adam,softmax

# %%
model_1 = keras.Sequential([
    keras.layers.Dense(10, input_shape=(784,), activation='softmax')
])

model_1.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy']
              )
model_1.summary()
#param_number = output_channel_number * (input_channel_number + 1)
history=model_1.fit(X_train_scaled, Y_train,validation_data=(X_test_scaled, Y_test), epochs=10)
# Out:
# WARNING:tensorflow:From C:\Users\91956\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\91956\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                7850
#
# =================================================================
# Total params: 7850 (30.66 KB)
# Trainable params: 7850 (30.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\91956\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\91956\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4677 - accuracy: 0.8750 - val_loss: 0.3087 - val_accuracy: 0.9158
# Epoch 2/10
# 1875/1875 [==============================] - 2s 900us/step - loss: 0.3039 - accuracy: 0.9150 - val_loss: 0.2795 - val_accuracy: 0.9229
# Epoch 3/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2833 - accuracy: 0.9209 - val_loss: 0.2720 - val_accuracy: 0.9245
# Epoch 4/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2726 - accuracy: 0.9237 - val_loss: 0.2746 - val_accuracy: 0.9218
# Epoch 5/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2664 - accuracy: 0.9256 - val_loss: 0.2665 - val_accuracy: 0.9261
# Epoch 6/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2618 - accuracy: 0.9266 - val_loss: 0.2672 - val_accuracy: 0.9272
# Epoch 7/10
# 1875/1875 [==============================] - 2s 976us/step - loss: 0.2583 - accuracy: 0.9284 - val_loss: 0.2648 - val_accuracy: 0.9277
# Epoch 8/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2559 - accuracy: 0.9295 - val_loss: 0.2662 - val_accuracy: 0.9267
# Epoch 9/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2529 - accuracy: 0.9301 - val_loss: 0.2639 - val_accuracy: 0.9283
# Epoch 10/10
# 1875/1875 [==============================] - 2s 904us/step - loss: 0.2509 - accuracy: 0.9303 - val_loss: 0.2636 - val_accuracy: 0.9264

# %%
model_1.evaluate(X_test_scaled, Y_test)
# Out:
# 313/313 [==============================] - 0s 878us/step - loss: 0.2636 - accuracy: 0.9264
# [0.2635918855667114, 0.9264000058174133]

# %%
plt.grid()
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['loss'], label = 'train_loss')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([-0.5, 1.2])
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## 4.2  Neural Network Using hidden layer - Adam,softmax

# %%
model_2 = keras.Sequential([
    keras.layers.Dense(100,input_shape=(784,),activation='relu'),
    keras.layers.Dense(50, activation='relu'),
    keras.layers.Dense(30, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model_2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model_2.summary()
#param_number = output_channel_number * (input_channel_number + 1)

history=model_2.fit(X_train_scaled, Y_train, validation_data=(X_test_scaled, Y_test),epochs=10)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 100)               78500
#
#  dense_2 (Dense)             (None, 50)                5050
#
#  dense_3 (Dense)             (None, 30)                1530
#
#  dense_4 (Dense)             (None, 10)                310
#
# =================================================================
# Total params: 85390 (333.55 KB)
# Trainable params: 85390 (333.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2808 - accuracy: 0.9152 - val_loss: 0.1227 - val_accuracy: 0.9622
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1143 - accuracy: 0.9658 - val_loss: 0.1010 - val_accuracy: 0.9695
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0839 - accuracy: 0.9744 - val_loss: 0.0889 - val_accuracy: 0.9709
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0657 - accuracy: 0.9796 - val_loss: 0.0898 - val_accuracy: 0.9717
# Epoch 5/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0519 - accuracy: 0.9829 - val_loss: 0.0759 - val_accuracy: 0.9789
# Epoch 6/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0448 - accuracy: 0.9859 - val_loss: 0.0896 - val_accuracy: 0.9752
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0392 - accuracy: 0.9874 - val_loss: 0.1014 - val_accuracy: 0.9735
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0331 - accuracy: 0.9896 - val_loss: 0.0848 - val_accuracy: 0.9766
# Epoch 9/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0285 - accuracy: 0.9906 - val_loss: 0.0977 - val_accuracy: 0.9755
# Epoch 10/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0249 - accuracy: 0.9919 - val_loss: 0.1064 - val_accuracy: 0.9742

# %%
model_2.evaluate(X_test_scaled, Y_test)
# Out:
# 313/313 [==============================] - 0s 893us/step - loss: 0.1064 - accuracy: 0.9742
# [0.1064165011048317, 0.9742000102996826]

# %%
plt.grid()
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['loss'], label = 'train_loss')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([-0.5, 1.2])
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## 4.3 Neural Network Using hidden layer - Adam,Sigmoid

# %%
model_3 = keras.Sequential([
    keras.layers.Dense(100,input_shape=(784,),activation='relu'),
    keras.layers.Dense(50, activation='relu'),
    keras.layers.Dense(30, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model_3.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_3.summary()
#param_number = output_channel_number * (input_channel_number + 1)

history=model_3.fit(X_train_scaled, Y_train_saved, validation_data=(X_test_scaled, Y_test_saved),epochs=10)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 100)               78500
#
#  dense_6 (Dense)             (None, 50)                5050
#
#  dense_7 (Dense)             (None, 30)                1530
#
#  dense_8 (Dense)             (None, 10)                310
#
# =================================================================
# Total params: 85390 (333.55 KB)
# Trainable params: 85390 (333.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2666 - accuracy: 0.9220 - val_loss: 0.1458 - val_accuracy: 0.9575
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1133 - accuracy: 0.9658 - val_loss: 0.1050 - val_accuracy: 0.9681
# Epoch 3/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0816 - accuracy: 0.9751 - val_loss: 0.1138 - val_accuracy: 0.9662
# Epoch 4/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0658 - accuracy: 0.9797 - val_loss: 0.0968 - val_accuracy: 0.9715
# Epoch 5/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0526 - accuracy: 0.9835 - val_loss: 0.0951 - val_accuracy: 0.9718
# Epoch 6/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0441 - accuracy: 0.9858 - val_loss: 0.1011 - val_accuracy: 0.9709
# Epoch 7/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0376 - accuracy: 0.9878 - val_loss: 0.0873 - val_accuracy: 0.9756
# Epoch 8/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0320 - accuracy: 0.9898 - val_loss: 0.1005 - val_accuracy: 0.9741
# Epoch 9/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0292 - accuracy: 0.9913 - val_loss: 0.0980 - val_accuracy: 0.9740
# Epoch 10/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0250 - accuracy: 0.9918 - val_loss: 0.1413 - val_accuracy: 0.9653

# %%
model_3.evaluate(X_test_scaled, Y_test_saved)
# Out:
# 313/313 [==============================] - 0s 867us/step - loss: 0.1413 - accuracy: 0.9653
# [0.1413007378578186, 0.9653000235557556]

# %%
plt.grid()
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['loss'], label = 'train_loss')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([-0.5, 1.2])
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## 4.4 Neural Network Using hidden layer - SGD,Softmax

# %%
model_4 = keras.Sequential([
    keras.layers.Dense(100,input_shape=(784,),activation='relu'),
    keras.layers.Dense(50, activation='relu'),
    keras.layers.Dense(30, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model_4.compile(optimizer='SGD',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model_4.summary()
#param_number = output_channel_number * (input_channel_number + 1)

history=model_4.fit(X_train_scaled, Y_train, validation_data=(X_test_scaled, Y_test),epochs=10)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 100)               78500
#
#  dense_10 (Dense)            (None, 50)                5050
#
#  dense_11 (Dense)            (None, 30)                1530
#
#  dense_12 (Dense)            (None, 10)                310
#
# =================================================================
# Total params: 85390 (333.55 KB)
# Trainable params: 85390 (333.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.7711 - accuracy: 0.7699 - val_loss: 0.3303 - val_accuracy: 0.9067
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2954 - accuracy: 0.9142 - val_loss: 0.2471 - val_accuracy: 0.9306
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2326 - accuracy: 0.9333 - val_loss: 0.2127 - val_accuracy: 0.9362
# Epoch 4/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1943 - accuracy: 0.9438 - val_loss: 0.1968 - val_accuracy: 0.9418
# Epoch 5/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1667 - accuracy: 0.9517 - val_loss: 0.1603 - val_accuracy: 0.9522
# Epoch 6/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1450 - accuracy: 0.9578 - val_loss: 0.1455 - val_accuracy: 0.9563
# Epoch 7/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1289 - accuracy: 0.9628 - val_loss: 0.1343 - val_accuracy: 0.9594
# Epoch 8/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1153 - accuracy: 0.9671 - val_loss: 0.1265 - val_accuracy: 0.9613
# Epoch 9/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1037 - accuracy: 0.9698 - val_loss: 0.1182 - val_accuracy: 0.9631
# Epoch 10/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0945 - accuracy: 0.9722 - val_loss: 0.1157 - val_accuracy: 0.9639

# %%
model_4.evaluate(X_test_scaled, Y_test)
# Out:
# 313/313 [==============================] - 0s 881us/step - loss: 0.1157 - accuracy: 0.9639
# [0.11574935168027878, 0.9639000296592712]

# %%
plt.grid()
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['loss'], label = 'train_loss')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([-0.5, 1.2])
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## 4.5 Neural Network Using hidden layer - SGD,Sigmoid

# %%
model_5 = keras.Sequential([
    keras.layers.Dense(100,input_shape=(784,),activation='relu'),
    keras.layers.Dense(50, activation='relu'),
    keras.layers.Dense(30, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model_5.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_5.summary()
#param_number = output_channel_number * (input_channel_number + 1)

history=model_5.fit(X_train_scaled, Y_train_saved, validation_data=(X_test_scaled, Y_test_saved),epochs=10)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 100)               78500
#
#  dense_14 (Dense)            (None, 50)                5050
#
#  dense_15 (Dense)            (None, 30)                1530
#
#  dense_16 (Dense)            (None, 10)                310
#
# =================================================================
# Total params: 85390 (333.55 KB)
# Trainable params: 85390 (333.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.7003 - accuracy: 0.7993 - val_loss: 0.3011 - val_accuracy: 0.9114
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2754 - accuracy: 0.9199 - val_loss: 0.2223 - val_accuracy: 0.9335
# Epoch 3/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2168 - accuracy: 0.9371 - val_loss: 0.1902 - val_accuracy: 0.9445
# Epoch 4/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1812 - accuracy: 0.9464 - val_loss: 0.1689 - val_accuracy: 0.9482
# Epoch 5/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1561 - accuracy: 0.9542 - val_loss: 0.1543 - val_accuracy: 0.9521
# Epoch 6/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1380 - accuracy: 0.9592 - val_loss: 0.1396 - val_accuracy: 0.9566
# Epoch 7/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1213 - accuracy: 0.9642 - val_loss: 0.1259 - val_accuracy: 0.9607
# Epoch 8/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1083 - accuracy: 0.9677 - val_loss: 0.1132 - val_accuracy: 0.9631
# Epoch 9/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0981 - accuracy: 0.9710 - val_loss: 0.1052 - val_accuracy: 0.9650
# Epoch 10/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0894 - accuracy: 0.9740 - val_loss: 0.1059 - val_accuracy: 0.9660

# %%
model_5.evaluate(X_test_scaled, Y_test_saved)
# Out:
# 313/313 [==============================] - 0s 930us/step - loss: 0.1059 - accuracy: 0.9660
# [0.10593051463365555, 0.9660000205039978]

# %%
plt.grid()
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['loss'], label = 'train_loss')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([-0.5, 1.2])
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # 5.Performance Matrix

# %%
y_predicted = model_2.predict(X_test_scaled)
y_predicted_labels = [np.argmax(i) for i in y_predicted]
cm = tf.math.confusion_matrix(labels=Y_test_saved,predictions=y_predicted_labels)
cm
# Out:
# 313/313 [==============================] - 0s 1ms/step
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 968,    0,    1,    1,    0,    2,    4,    1,    2,    1],
#        [   0, 1127,    0,    1,    0,    0,    2,    1,    4,    0],
#        [   5,    3,  974,   23,    3,    2,    1,    7,   14,    0],
#        [   1,    0,    3,  979,    0,   12,    0,    7,    3,    5],
#        [   1,    0,    4,    0,  960,    0,    4,    6,    0,    7],
#        [   2,    0,    0,    5,    1,  877,    2,    0,    4,    1],
#        [   1,    3,    0,    0,    5,    5,  943,    0,    1,    0],
#        [   1,    5,    7,    4,    1,    0,    0, 1002,    1,    7],
#        [   3,    0,    2,    8,    5,    3,    3,    3,  939,    8],
#        [   2,    3,    0,    2,   14,    4,    0,   10,    1,  973]])>

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()

# %% [markdown]
# # 6. Summary
# 1. Very simple neural network with no hidden layers  - accuray=92% (test and train) , Trainable params: 7,850.
#
# 2. Very simple neural network with hidden layer(100-50-30-10) - accuray=97%(test=99% and train=97%),Trainable params: 85,390

# %% [markdown]
# # 7. Not Covered in this notebook
# 1. Dropout layers , Batch Normalization(BN) - Regularization
# 2. Batch size - in model.fit
# 3. Hyper - Parameter tuning - Number of layers , activation functions(Relu,sigmoid,tanh),
# Optimizers(SGD, Adam)
