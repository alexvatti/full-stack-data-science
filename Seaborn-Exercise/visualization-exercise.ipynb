# %% [markdown]
# # Visualization Exercise

# %% [markdown]
# ## Seaborn
#
#     1. Bar Plot
#     2. Pie Plot(matplotlib)
#     3. Heatmap
#     4. Box Plot
#     5. Pair Plot
#     6. Violin Plot
#     7. Count Plot
#     8. Kde Plot

# %% [markdown]
# ## 1. Bar Plot
#
# A bar plot or bar chart is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
tips = pd.read_csv("tips.csv")

print(tips.head())
print(tips.columns)

# visualization
plt.figure(figsize=(7,5))
ax = sns.barplot(x="day", y="total_bill", data=tips)
plt.xlabel("day")
plt.ylabel("bill")
plt.title("day vs bills")
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# **Observations**
# 1. Highest to lowest:bill paid to service: Sunday,Saturday, Thursday, Friday

# %%
# importing the required library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# read a titanic.csv file
# from seaborn library
titanic = pd.read_csv('titanic.csv')
# who v/s fare barplot
print(titanic.head())
print(titanic.columns)
print(titanic.dtypes)
sns.barplot(x = 'Pclass',y = "Survived", data = titanic)
# Show the plot
plt.xlabel("Class")
plt.ylabel("Survived")
plt.title("Class vs Survived")
plt.show()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %% [markdown]
# **Observations**
# 1. Survived Highest to lowest: Class 1, Class 2, Class 3

# %% [markdown]
#  ## 2. Pie Plot
#  A Pie Chart is a circular statistical plot that can display only one series of data. The area of the chart is the total percentage of the given data. The area of slices of the pie represents the percentage of the parts of the data.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
iris = pd.read_csv("iris.csv")
print(iris.head())
print(iris.columns)

flowers = iris.species.unique()
print(flowers)
print(iris.species.value_counts())

plt.pie(iris.species.value_counts(), labels=flowers, autopct='%1.1f%%', startangle=50)
#plt.pie(labels=flowers,x=iris.species.value_counts())
plt.show()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
# ['setosa' 'versicolor' 'virginica']
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# **Observations**
# 1. Iris dataset contain three equal species : 'setosa', 'versicolor', 'virginica'

# %%
print(titanic.head())
print(titanic.columns)
print(titanic.Survived.value_counts())
plt.pie(labels=["not-survived","survived"],x=titanic.Survived.value_counts(),autopct='%1.1f%%')
plt.show()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %% [markdown]
# **Observations**
# 1. Survived =38% , Non-Survived=62%

# %% [markdown]
# ## 3. Heatmap
# Plot rectangular data as a color-encoded matrix.
# 1. The correlation coefficient has values between -1 to 1
# 2. A value closer to 0 implies weaker correlation (exact 0 implying no correlation)
# 3. A value closer to 1 implies stronger positive correlation
# 4. A value closer to -1 implies stronger negative correlation

# %%
plt.figure(figsize=(7,4))
numerical_columns = iris.select_dtypes(include='number')
sns.heatmap(numerical_columns.corr(),annot=True,cmap="coolwarm")
plt.show()

# %%
#Correlation with output variable
cor=iris.corr()
cor_target = abs(cor["petal_width"])#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# sepal_length    0.817941
# petal_length    0.962865
# petal_width     1.000000
# Name: petal_width, dtype: float64

# %% [markdown]
# **Observations**
# 1.  dark color shows the high correlation between the values and the light colors shows less correlation between the variables

# %%
plt.figure(figsize=(10,8))
sns.heatmap(titanic.corr(),annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 plt.figure(figsize=(10,8))
# ----> 2 sns.heatmap(titanic.corr(),annot=True)
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...

# %% [markdown]
# ## 4. Box Plot
# A Box and Whisker Plot (or Box Plot) is a convenient way of visually displaying the data distribution through their quartiles.

# %%
sns.set_theme(style="whitegrid")
print(tips.head())
print(tips.columns)
# visualization
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# **Observations**
# 1. There are outliers towards upper extreme

# %%
print(iris.head())
print(iris.columns)
l = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
fig,ax = plt.subplots(2,2,figsize=(12,12))
fig.suptitle('Box-Plots')
for i in range(0,2):
    for j in range(0,2):
        feature_name=l.pop()
        sns.boxplot(x="species", y=feature_name, data=iris, ax=ax[i,j],orient="v")
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# **Observations**
# 1. Setosa w.r.t petal width has outliers towards upper extreme
# 2. Setosa w.r.t petal length has outliers towards upper and lower extreme
# 3. setosa,  virginica w.r.t sepal width has outliers towards upper and lower extreme
# 4. virginica w.r.t sepal length has outliers towards lower extreme
# 5. versicolor w.r.t petal length has outliers towards lower extreme

# %% [markdown]
# ## 5. Pair Plot
# To plot multiple pairwise bivariate distributions in a dataset, you can use the pairplot() function

# %%
sns.set(font_scale=1.5)
sns.pairplot(data = iris, kind = "scatter", hue="species", aspect =1, height = 3)
plt.show()
# Out:
# C:\Users\91956\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Observations**
# 1. petal length, petal width, sepal length and sepal width  - A bell curve is a common type of distribution for a variable, also known as the normal distribution.
# 2. petal length, petal width - distributions are separated
# 3. sepal length and sepal width - distributions are highly overlapped

# %%
print(tips.head())
print(tips.columns)
# visualization
sns.set(font_scale=1.5)
sns.pairplot(data = tips, kind = "scatter", hue="smoker", aspect =1, height = 3)
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
# C:\Users\91956\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 6. Violin Plot
# A violin plot is a hybrid of a box plot and a kernel density plot, which shows peaks in the data

# %%
sns.set_style("whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(15, 15))
fig.suptitle('Violin-Plots')
l = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
for i in range(0,2):
    for j in range(0,2):
        feature_name=l.pop()
        sns.violinplot(ax=axes[i, j], x='species',y=feature_name, data=iris)
plt.show()

# %% [markdown]
# ## 7. countplot
# method is used to Show the counts of observations in each categorical bin using bars.

# %%
print(titanic.dtypes)
sns.set_theme(style="darkgrid")
sns.countplot(x="Pclass ", hue='Survived', data=titanic)
plt.show()
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 3
#       1 print(titanic.dtypes)
#       2 sns.set_theme(style="darkgrid")
# ----> 3 sns.countplot(x="Pclass ", hue='Survived', data=titanic)
#       4 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
# ...

# %% [markdown]
# **Observations**
# 1. First-class  Passengers: survived is more than not-survivied (survived:non-survived=2:1)
# 2. Second-class Passengers:  both survived and not-survived are almost same (survived:non-survived=1:1)
# 3. Third -class Passengers: Not survived is far more than survived(survived:non-survived=1:3)

# %%
sns.countplot(x="Sex", hue='Survived', data=titanic)
plt.show()

# %% [markdown]
# **Observations**
# 1. Survived Male Passengers is less compared to female Passengers
# 2. Male Passengers (Survived : Non Survived=1:4)
# 3. Female Passengers (Survived : Non Survived=3:1)

# %%
sns.countplot(x="species", data=iris)
plt.show()

# %% [markdown]
# **Observations**
# 1. Three flow types are equal ,count=50, balanced dataset

# %%
sns.countplot(x="day",hue="sex", data=tips)
plt.show()

# %% [markdown]
# **Observations**
# 1. Visits of Male,Female to Restaurants on Thurday and Friday is same. (1:1)
# 2. Visits of Male to Restaurants is far more in Saturday and Sunday more than female. (Male:Female=2:1)

# %% [markdown]
# ## 8. Kde Plot
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram

# %%
sns.set_style("whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
fig.suptitle('Kde-Plots')
l = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
for i in range(0,2):
    for j in range(0,2):
        name=l.pop()
        sns.histplot(ax=axes[i, j], hue='species',x=name, data=iris,kde=True)
plt.show()

# %% [markdown]
# **Observations**
# 1. Bell Shaped Curve -  used to depict a normal distribution consists of a symmetrical bell-shaped curve.

# %% [markdown]
# **Summary**
# 1. Continuous Variables - find Outliers , Shape and Distribution-use -
#     Box Plot , Violin, Kde Plot
# 2. Correlation Between Variables - Heatmap
# 3. Categorical Variables - Hist, Count plots
# 4. RelationShip between Variables - line, Scatter , Pair Plots
