# %% [markdown]
# # Gradient boost

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import pandas as pd

# %%
# Create a dictionary containing the data
data = {
    'Years of Exp': [1, 1.5, 2.5, 3, 5, 6],
    'Gap': [0, 1, 1, 0, 0, 0],
    'Annual salary': [4, 4, 5.5, 7, 7.5, 8]
}
# Create a pandas DataFrame from the dictionary
df = pd.DataFrame(data)

X=df.drop('Annual salary',axis=1)
Y=df["Annual salary"]

# %%
# Create a decision tree regressor with a maximum depth of 1
predicted_values = np.full_like(Y, np.mean(Y))
print("base -predicted:", predicted_values)
error_values = np.array(Y - np.mean(Y))
print("base-errors",error_values)

for i in range(30):
    
    tree_reg = DecisionTreeRegressor(max_depth=1)
    tree_reg.fit(X, error_values)

    # Find the average target value in each leaf node
    # Leaf nodes can be found using the tree's `apply` method
    leaf_nodes = tree_reg.apply(X)

    leaf_values = {}
    for node in set(leaf_nodes):
        leaf_values[node] = error_values[leaf_nodes == node].mean()

    # Create a target column based on the average target value of the leaf node
    target_column = np.array([leaf_values[node] for node in leaf_nodes])

    # Print the target column
    print("Target column based on leaf node averages:")
    print(target_column)
    predicted_values=predicted_values+0.1*(target_column)
    print("base -predicted:", predicted_values)
    error_values = np.array(Y - predicted_values)
    
    print("base-errors",error_values)
    print("=============================================")

# test set RMSE
test_rmse = mean_squared_error(Y, predicted_values) ** (1 / 2)
 
# Print rmse
print('Root mean Square error: {:.2f}'.format(test_rmse))
# Out:
# base -predicted: [6. 6. 6. 6. 6. 6.]
# base-errors [-2.  -2.  -0.5  1.   1.5  2. ]
# Target column based on leaf node averages:
# [-1.5 -1.5 -1.5  1.5  1.5  1.5]
# base -predicted: [5.85 5.85 5.85 6.15 6.15 6.15]
# base-errors [-1.85 -1.85 -0.35  0.85  1.35  1.85]
# =============================================
# Target column based on leaf node averages:
# [-1.35 -1.35 -1.35  1.35  1.35  1.35]
# base -predicted: [5.715 5.715 5.715 6.285 6.285 6.285]
# base-errors [-1.715 -1.715 -0.215  0.715  1.215  1.715]
# =============================================
# Target column based on leaf node averages:
# [-1.215 -1.215 -1.215  1.215  1.215  1.215]
# base -predicted: [5.5935 5.5935 5.5935 6.4065 6.4065 6.4065]
# base-errors [-1.5935 -1.5935 -0.0935  0.5935  1.0935  1.5935]
# =============================================
# Target column based on leaf node averages:
# [-1.5935  -1.5935   0.79675  0.79675  0.79675  0.79675]
# base -predicted: [5.43415  5.43415  5.673175 6.486175 6.486175 6.486175]
# base-errors [-1.43415  -1.43415  -0.173175  0.513825  1.013825  1.513825]
# =============================================
# Target column based on leaf node averages:
# [-1.43415  -1.43415   0.717075  0.717075  0.717075  0.717075]
# base -predicted: [5.290735  5.290735  5.7448825 6.5578825 6.5578825 6.5578825]
# base-errors [-1.290735  -1.290735  -0.2448825  0.4421175  0.9421175  1.4421175]
# =============================================
# Target column based on leaf node averages:
# [-0.9421175 -0.9421175 -0.9421175  0.9421175  0.9421175  0.9421175]
# base -predicted: [5.19652325 5.19652325 5.65067075 6.65209425 6.65209425 6.65209425]
# base-errors [-1.19652325 -1.19652325 -0.15067075  0.34790575  0.84790575  1.34790575]
# =============================================
# Target column based on leaf node averages:
# [-0.84790575 -0.84790575 -0.84790575  0.84790575  0.84790575  0.84790575]
# base -predicted: [5.11173267 5.11173267 5.56588017 6.73688483 6.73688483 6.73688483]
# base-errors [-1.11173267 -1.11173267 -0.06588017  0.26311517  0.76311517  1.26311517]
# =============================================
# Target column based on leaf node averages:
# [-1.11173267 -1.11173267  0.55586634  0.55586634  0.55586634  0.55586634]
# base -predicted: [5.00055941 5.00055941 5.62146681 6.79247146 6.79247146 6.79247146]
# base-errors [-1.00055941 -1.00055941 -0.12146681  0.20752854  0.70752854  1.20752854]
# =============================================
# Target column based on leaf node averages:
# [-0.70752854 -0.70752854 -0.70752854  0.70752854  0.70752854  0.70752854]
# base -predicted: [4.92980655 4.92980655 5.55071395 6.86322431 6.86322431 6.86322431]
# base-errors [-0.92980655 -0.92980655 -0.05071395  0.13677569  0.63677569  1.13677569]
# =============================================
# Target column based on leaf node averages:
# [-0.92980655 -0.92980655  0.46490328  0.46490328  0.46490328  0.46490328]
# base -predicted: [4.8368259  4.8368259  5.59720428 6.90971464 6.90971464 6.90971464]
# base-errors [-0.8368259  -0.8368259  -0.09720428  0.09028536  0.59028536  1.09028536]
# =============================================
# Target column based on leaf node averages:
# [-0.42014268 -0.42014268 -0.42014268 -0.42014268  0.84028536  0.84028536]
# base -predicted: [4.79481163 4.79481163 5.55519001 6.86770037 6.99374318 6.99374318]
# base-errors [-0.79481163 -0.79481163 -0.05519001  0.13229963  0.50625682  1.00625682]
# =============================================
# Target column based on leaf node averages:
# [-0.79481163 -0.79481163  0.39740582  0.39740582  0.39740582  0.39740582]
# base -predicted: [4.71533047 4.71533047 5.5949306  6.90744095 7.03348376 7.03348376]
# base-errors [-0.71533047 -0.71533047 -0.0949306   0.09255905  0.46651624  0.96651624]
# =============================================
# Target column based on leaf node averages:
# [-0.50853051 -0.50853051 -0.50853051  0.50853051  0.50853051  0.50853051]
# base -predicted: [4.66447742 4.66447742 5.54407754 6.95829401 7.08433681 7.08433681]
# base-errors [-0.66447742 -0.66447742 -0.04407754  0.04170599  0.41566319  0.91566319]
# =============================================
# Target column based on leaf node averages:
# [-0.3328316  -0.3328316  -0.3328316  -0.3328316   0.66566319  0.66566319]
# base -predicted: [4.63119426 4.63119426 5.51079439 6.92501085 7.15090313 7.15090313]
# base-errors [-0.63119426 -0.63119426 -0.01079439  0.07498915  0.34909687  0.84909687]
# =============================================
# Target column based on leaf node averages:
# [-0.63119426 -0.63119426  0.31559713  0.31559713  0.31559713  0.31559713]
# base -predicted: [4.56807483 4.56807483 5.5423541  6.95657056 7.18246284 7.18246284]
# base-errors [-0.56807483 -0.56807483 -0.0423541   0.04342944  0.31753716  0.81753716]
# =============================================
# Target column based on leaf node averages:
# [-0.56807483 -0.56807483  0.28403742  0.28403742  0.28403742  0.28403742]
# base -predicted: [4.51126735 4.51126735 5.57075784 6.9849743  7.21086658 7.21086658]
# base-errors [-0.51126735 -0.51126735 -0.07075784  0.0150257   0.28913342  0.78913342]
# =============================================
# Target column based on leaf node averages:
# [-0.26956671 -0.26956671 -0.26956671 -0.26956671  0.53913342  0.53913342]
# base -predicted: [4.48431068 4.48431068 5.54380117 6.95801763 7.26477992 7.26477992]
# base-errors [-0.48431068 -0.48431068 -0.04380117  0.04198237  0.23522008  0.73522008]
# =============================================
# Target column based on leaf node averages:
# [-0.24261004 -0.24261004 -0.24261004 -0.24261004  0.48522008  0.48522008]
# base -predicted: [4.46004967 4.46004967 5.51954016 6.93375663 7.31330193 7.31330193]
# base-errors [-0.46004967 -0.46004967 -0.01954016  0.06624337  0.18669807  0.68669807]
# =============================================
# Target column based on leaf node averages:
# [-0.46004967 -0.46004967  0.23002484  0.23002484  0.23002484  0.23002484]
# base -predicted: [4.41404471 4.41404471 5.54254265 6.95675911 7.33630442 7.33630442]
# base-errors [-0.41404471 -0.41404471 -0.04254265  0.04324089  0.16369558  0.66369558]
# =============================================
# Target column based on leaf node averages:
# [-0.13273912 -0.13273912 -0.13273912 -0.13273912 -0.13273912  0.66369558]
# base -predicted: [4.40077079 4.40077079 5.52926874 6.9434852  7.3230305  7.40267397]
# base-errors [-0.40077079 -0.40077079 -0.02926874  0.0565148   0.1769695   0.59732603]
# =============================================
# Target column based on leaf node averages:
# [-0.40077079 -0.40077079  0.2003854   0.2003854   0.2003854   0.2003854 ]
# base -predicted: [4.36069371 4.36069371 5.54930728 6.96352374 7.34306904 7.42271251]
# base-errors [-0.36069371 -0.36069371 -0.04930728  0.03647626  0.15693096  0.57728749]
# =============================================
# Target column based on leaf node averages:
# [-0.18355461 -0.18355461 -0.18355461 -0.18355461  0.36710922  0.36710922]
# base -predicted: [4.34233825 4.34233825 5.53095182 6.94516828 7.37977997 7.45942344]
# base-errors [-0.34233825 -0.34233825 -0.03095182  0.05483172  0.12022003  0.54057656]
# =============================================
# Target column based on leaf node averages:
# [-0.34233825 -0.34233825  0.17116913  0.17116913  0.17116913  0.17116913]
# base -predicted: [4.30810443 4.30810443 5.54806873 6.96228519 7.39689688 7.47654035]
# base-errors [-0.30810443 -0.30810443 -0.04806873  0.03771481  0.10310312  0.52345965]
# =============================================
# Target column based on leaf node averages:
# [-0.10469193 -0.10469193 -0.10469193 -0.10469193 -0.10469193  0.52345965]
# base -predicted: [4.29763524 4.29763524 5.53759954 6.951816   7.38642769 7.52888631]
# base-errors [-0.29763524 -0.29763524 -0.03759954  0.048184    0.11357231  0.47111369]
# =============================================
# Target column based on leaf node averages:
# [-0.21095667 -0.21095667 -0.21095667  0.21095667  0.21095667  0.21095667]
# base -predicted: [4.27653957 4.27653957 5.51650387 6.97291166 7.40752335 7.54998198]
# base-errors [-0.27653957 -0.27653957 -0.01650387  0.02708834  0.09247665  0.45001802]
# =============================================
# Target column based on leaf node averages:
# [-0.0900036  -0.0900036  -0.0900036  -0.0900036  -0.0900036   0.45001802]
# base -predicted: [4.26753921 4.26753921 5.50750351 6.9639113  7.39852299 7.59498378]
# base-errors [-0.26753921 -0.26753921 -0.00750351  0.0360887   0.10147701  0.40501622]
# =============================================
# Target column based on leaf node averages:
# [-0.26753921 -0.26753921  0.1337696   0.1337696   0.1337696   0.1337696 ]
# base -predicted: [4.24078529 4.24078529 5.52088047 6.97728826 7.41189995 7.60836074]
# base-errors [-0.24078529 -0.24078529 -0.02088047  0.02271174  0.08810005  0.39163926]
# =============================================
# Target column based on leaf node averages:
# [-0.07832785 -0.07832785 -0.07832785 -0.07832785 -0.07832785  0.39163926]
# base -predicted: [4.2329525  4.2329525  5.51304768 6.96945548 7.40406717 7.64752467]
# base-errors [-0.2329525  -0.2329525  -0.01304768  0.03054452  0.09593283  0.35247533]
# =============================================
# Target column based on leaf node averages:
# [-0.2329525  -0.2329525   0.11647625  0.11647625  0.11647625  0.11647625]
# base -predicted: [4.20965725 4.20965725 5.52469531 6.9811031  7.41571479 7.65917229]
# base-errors [-0.20965725 -0.20965725 -0.02469531  0.0188969   0.08428521  0.34082771]
# =============================================
# Target column based on leaf node averages:
# [-0.06816554 -0.06816554 -0.06816554 -0.06816554 -0.06816554  0.34082771]
# base -predicted: [4.2028407  4.2028407  5.51787875 6.97428655 7.40889824 7.69325506]
# base-errors [-0.2028407  -0.2028407  -0.01787875  0.02571345  0.09110176  0.30674494]
# =============================================
# Root mean Square error: 0.18

# %%
# Create and fit the gradient boosting regressor model
from sklearn.ensemble import GradientBoostingRegressor
gb_regressor = GradientBoostingRegressor(loss='absolute_error',n_estimators=30)
gb_regressor.fit(X, Y)

# Predict on the test set
Y_pred = gb_regressor.predict(X)

# Calculate Mean Squared Error (MSE)
rmse = mean_squared_error(Y, Y_pred) ** (1 / 2)
print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 0.33509607056228347
