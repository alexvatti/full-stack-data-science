# %% [markdown]
# # 🚀 Objective: Backpropagation and  update Weights
# # 💡 Own Code: Python Implementation for Digesting Concept
# # 🎯 Purpose: Mastering the Essence of Neural Network
#
# # Spl Thank you Nallagoni Omkar sir for your guidance.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# update wts , i did not consider bias in this exercise
import numpy as np
def linear_activation(w1,x1,w2,x2):
    #print(w1*x1+w2*x2)
    z=(w1*x1)+(w2*x2)
    #print(z)
    return(1/(1+np.exp(-z)))


x1=0.35
x2=0.7

# initial wts
w11=0.2
w12=0.3
w21=0.2
w22=0.3

w13=0.3
w23=0.9

actual = 0.5
epoch=50
learning_rate=0.3

for i in range(epoch):
    h1=linear_activation(w11,x1,w21,x2)
    h2=linear_activation(w12,x1,w22,x2)
    output=linear_activation(w13,oh1,w23,oh2)
    
    loss = actual - output
    print("iteration:",i, "actual",actual,"output",output,"loss",loss)
    
    w13=w13 + learning_rate*(loss*h1)
    w23=w23 + learning_rate*(loss*h2)

    w11 = w11 + learning_rate*(loss*w13*x1)
    w21 = w21 + learning_rate*(loss*w13*x2)

    w12 = w12 + learning_rate*(loss*w23*x1)
    w22 = w22 + learning_rate*(loss*w23*x2)

print("\nFinal Wts\n")
print("w11",w11)
print("w12",w12)
print("w21",w21)
print("w22",w22)
print("w13",w13)
print("w23",w23)
# Out:
# iteration: 0 actual 0.5 output 0.6650736395247564 loss -0.1650736395247564
# iteration: 1 actual 0.5 output 0.6579855765029582 loss -0.1579855765029582
# iteration: 2 actual 0.5 output 0.6511874722973061 loss -0.1511874722973061
# iteration: 3 actual 0.5 output 0.6446700050154781 loss -0.1446700050154781
# iteration: 4 actual 0.5 output 0.6384236699677183 loss -0.13842366996771827
# iteration: 5 actual 0.5 output 0.6324388935051111 loss -0.13243889350511107
# iteration: 6 actual 0.5 output 0.6267061230141886 loss -0.1267061230141886
# iteration: 7 actual 0.5 output 0.621215897341582 loss -0.121215897341582
# iteration: 8 actual 0.5 output 0.6159589012382081 loss -0.11595890123820807
# iteration: 9 actual 0.5 output 0.6109260068136398 loss -0.11092600681363984
# iteration: 10 actual 0.5 output 0.6061083044763078 loss -0.10610830447630781
# iteration: 11 actual 0.5 output 0.6014971253981445 loss -0.10149712539814448
# ...

# %% [markdown]
# # Conclusion
#
# 1. Will Explore the Concepts - Will Get Back with New Updates
