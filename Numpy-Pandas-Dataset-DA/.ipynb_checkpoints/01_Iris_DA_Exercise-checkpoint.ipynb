# %%
##

# %% [markdown]
# # DATASET - IRIS
# 1. Classify Flower Types, based on features provided
# 2. Reduce the Manpower to classify
# 3. Use Machine learning - Data Science

# %% [markdown]
# ## load Python Modules

# %%
# Load necessary pyhton modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load IRIS Dataset

# %%
iris = pd.read_csv("dataset\IRIS.csv")

# %% [markdown]
# ## Basic Inspection on dataset

# %%
def basic_inspection(table):
    print("Top 5 Sample of dataset")
    print(table.head())
    print("Bottom 5 Sample of dataset")
    print(table.tail())
    print("Column - Names of Given dataset")
    print(table.columns)
    print()
    print("Shape(rows x columns) - of Given dataset")
    print(table.shape)
    print()
    print("Data types - Column Names")
    print(table.dtypes)
    print()
    print("Summry of dataset")
    print(table.info())
    print()
    print("To see the count of null/nan values in columns of dataset")
    print(table.isnull().value_counts())
    print()
    print("Dataset Summary ")
    print(table.describe())
    print()
    print(table["Species"].unique())
basic_inspection(iris)
# Out:
# Top 5 Sample of dataset
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# Bottom 5 Sample of dataset
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# ...

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ###  Categorical variables

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
flower_names=["setosa","versicolor","virginica"]
values = list(iris["Species"].value_counts())
bars = axs[0].bar(flower_names,values)
# Adding count values on top of the bars
for bar, value in zip(bars, values):
    axs[0].text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value),   ha='center', va='bottom')
axs[1].pie(values,labels=flower_names,autopct="%.2f")
fig.suptitle('Flowers')
plt.show()

# %% [markdown]
# ### Continuous variables

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs[0][0].hist(iris["SepalLengthCm"], bins=10, color='skyblue', edgecolor='black')
axs[0][1].hist(iris["SepalWidthCm"], bins=10, color='skyblue', edgecolor='black')
axs[1][0].hist(iris["PetalLengthCm"], bins=10, color='skyblue', edgecolor='black')
axs[1][1].hist(iris["PetalWidthCm"], bins=10, color='skyblue', edgecolor='black')

# Adding labels and title to each subplot
axs[0, 0].set_xlabel('Sepal Length (cm)')
axs[0, 0].set_ylabel('Frequency')
axs[0, 0].set_title('Histogram - Sepal Length')

axs[0, 1].set_xlabel('Sepal Width (cm)')
axs[0, 1].set_ylabel('Frequency')
axs[0, 1].set_title('Histogram - Sepal Width')

axs[1, 0].set_xlabel('Petal Length (cm)')
axs[1, 0].set_ylabel('Frequency')
axs[1, 0].set_title('Histogram - Petal Length')

axs[1, 1].set_xlabel('Petal Width (cm)')
axs[1, 1].set_ylabel('Frequency')
axs[1, 1].set_title('Histogram - Petal Width')

# Adjust layout to prevent overlapping titles
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 15))

# Box plot for Sepal Length
axs[0, 0].boxplot(iris["SepalLengthCm"])
axs[0, 0].set_title('Box Plot - Sepal Length')
axs[0, 0].grid(True)  # Add grid

# Box plot for Sepal Width
axs[0, 1].boxplot(iris["SepalWidthCm"])
axs[0, 1].set_title('Box Plot - Sepal Width')
axs[0, 1].grid(True)  # Add grid

# Box plot for Petal Length
axs[1, 0].boxplot(iris["PetalLengthCm"])
axs[1, 0].set_title('Box Plot - Petal Length')
axs[1, 0].grid(True)  # Add grid

# Box plot for Petal Width
axs[1, 1].boxplot(iris["PetalWidthCm"])
axs[1, 1].set_title('Box Plot - Petal Width')
axs[1, 1].grid(True)  # Add grid

# Adjust layout to prevent overlapping titles
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 15))

# Violin plot for Sepal Length
sns.violinplot(x=iris["SepalLengthCm"], ax=axs[0, 0], color='skyblue')
axs[0, 0].set_title('Violin Plot - Sepal Length')

# Violin plot for Sepal Width
sns.violinplot(x=iris["SepalWidthCm"], ax=axs[0, 1], color='skyblue')
axs[0, 1].set_title('Violin Plot - Sepal Width')

# Violin plot for Petal Length
sns.violinplot(x=iris["PetalLengthCm"], ax=axs[1, 0], color='skyblue')
axs[1, 0].set_title('Violin Plot - Petal Length')

# Violin plot for Petal Width
sns.violinplot(x=iris["PetalWidthCm"], ax=axs[1, 1], color='skyblue')
axs[1, 1].set_title('Violin Plot - Petal Width')

# Adjust layout to prevent overlapping titles
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 15))

# Kernel Density plot for Sepal Length
sns.kdeplot(iris["SepalLengthCm"], ax=axs[0, 0], color='skyblue', fill=True)
axs[0, 0].set_title('Kernel Density Plot - Sepal Length')

# Kernel Density plot for Sepal Width
sns.kdeplot(iris["SepalWidthCm"], ax=axs[0, 1], color='skyblue', fill=True)
axs[0, 1].set_title('Kernel Density Plot - Sepal Width')

# Kernel Density plot for Petal Length
sns.kdeplot(iris["PetalLengthCm"], ax=axs[1, 0], color='skyblue', fill=True)
axs[1, 0].set_title('Kernel Density Plot - Petal Length')

# Kernel Density plot for Petal Width
sns.kdeplot(iris["PetalWidthCm"], ax=axs[1, 1], color='skyblue', fill=True)
axs[1, 1].set_title('Kernel Density Plot - Petal Width')

# Adjust layout to prevent overlapping titles
plt.tight_layout()

# Display the plot
plt.show()

# %%
iris.plot(figsize = (15,15), subplots = True)
plt.show()

# %% [markdown]
# ### More-Complex Plots

# %%
sns.set_style("whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(15, 15))
fig.suptitle('Kde-Plots')
sns.histplot(ax=axes[0, 0], hue='Species',x='PetalWidthCm', data=iris,kde=True)
sns.histplot(ax=axes[0, 1], hue='Species',x='PetalLengthCm', data=iris,kde=True)
sns.histplot(ax=axes[1, 0], hue='Species',x='SepalWidthCm', data=iris,kde=True)
sns.histplot(ax=axes[1, 1], hue='Species',x='SepalLengthCm', data=iris,kde=True)
plt.show()

# %%
sns.set(font_scale=1.5)
iris_new = iris.drop(['Id'],axis='columns')
sns.pairplot(data = iris_new, kind = "scatter", hue="Species", aspect =1, height = 3)
plt.show()

# %%
#SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
sns.set_style("whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(15, 15))
fig.suptitle('Box-Plots')
sns.boxplot(ax=axes[0, 0], x='Species',y='PetalWidthCm', data=iris)
sns.boxplot(ax=axes[0, 1], x='Species',y='PetalLengthCm', data=iris)
sns.boxplot(ax=axes[1, 0], x='Species',y='SepalWidthCm', data=iris)
sns.boxplot(ax=axes[1, 1], x='Species',y='SepalLengthCm', data=iris)
plt.show()

# %%
sns.set_style("whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(15, 15))
fig.suptitle('Violin-Plots')
sns.violinplot(ax=axes[0, 0], x='Species',y='PetalWidthCm', data=iris)
sns.violinplot(ax=axes[0, 1], x='Species',y='PetalLengthCm', data=iris)
sns.violinplot(ax=axes[1, 0], x='Species',y='SepalWidthCm', data=iris)
sns.violinplot(ax=axes[1, 1], x='Species',y='SepalLengthCm', data=iris)
plt.show()

# %%
#['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
virginica_data_petalwidth = iris.groupby('Species').get_group('Iris-virginica')['PetalWidthCm'].tolist()
print(virginica_data_petalwidth)

versicolor_data_petalwidth = iris.groupby('Species').get_group('Iris-versicolor')['PetalWidthCm'].tolist()
print(versicolor_data_petalwidth)
# Out:
# [2.5, 1.9, 2.1, 1.8, 2.2, 2.1, 1.7, 1.8, 1.8, 2.5, 2.0, 1.9, 2.1, 2.0, 2.4, 2.3, 1.8, 2.2, 2.3, 1.5, 2.3, 2.0, 2.0, 1.8, 2.1, 1.8, 1.8, 1.8, 2.1, 1.6, 1.9, 2.0, 2.2, 1.5, 1.4, 2.3, 2.4, 1.8, 1.8, 2.1, 2.4, 2.3, 1.9, 2.3, 2.5, 2.3, 1.9, 2.0, 2.3, 1.8]
# [1.4, 1.5, 1.5, 1.3, 1.5, 1.3, 1.6, 1.0, 1.3, 1.4, 1.0, 1.5, 1.0, 1.4, 1.3, 1.4, 1.5, 1.0, 1.5, 1.1, 1.8, 1.3, 1.5, 1.2, 1.3, 1.4, 1.4, 1.7, 1.5, 1.0, 1.1, 1.0, 1.2, 1.6, 1.5, 1.6, 1.5, 1.3, 1.3, 1.3, 1.2, 1.4, 1.2, 1.0, 1.3, 1.2, 1.3, 1.3, 1.1, 1.3]

# %%
overlap_data = set(virginica_data_petalwidth).intersection(set(versicolor_data_petalwidth))
print(overlap_data)
print(len(overlap_data))

print(versicolor_data_petalwidth.count(1.8))
# Out:
# {1.7, 1.4, 1.8, 1.6, 1.5}
# 5
# 1

# %%
virginica_data_petallength = iris.groupby('Species').get_group('Iris-virginica')['PetalLengthCm'].tolist()
print(virginica_data_petallength)

versicolor_data_petallength = iris.groupby('Species').get_group('Iris-versicolor')['PetalLengthCm'].tolist()
print(versicolor_data_petallength)

overlap_data = set(virginica_data_petallength).intersection(set(versicolor_data_petallength))
print(overlap_data)
print(len(overlap_data))

print(versicolor_data_petallength.count(4.5))
# Out:
# [6.0, 5.1, 5.9, 5.6, 5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5, 5.0, 5.1, 5.3, 5.5, 6.7, 6.9, 5.0, 5.7, 4.9, 6.7, 4.9, 5.7, 6.0, 4.8, 4.9, 5.6, 5.8, 6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8, 5.4, 5.6, 5.1, 5.1, 5.9, 5.7, 5.2, 5.0, 5.2, 5.4, 5.1]
# [4.7, 4.5, 4.9, 4.0, 4.6, 4.5, 4.7, 3.3, 4.6, 3.9, 3.5, 4.2, 4.0, 4.7, 3.6, 4.4, 4.5, 4.1, 4.5, 3.9, 4.8, 4.0, 4.9, 4.7, 4.3, 4.4, 4.8, 5.0, 4.5, 3.5, 3.8, 3.7, 3.9, 5.1, 4.5, 4.5, 4.7, 4.4, 4.1, 4.0, 4.4, 4.6, 4.0, 3.3, 4.2, 4.2, 4.2, 4.3, 3.0, 4.1]
# {4.8, 5.0, 4.5, 4.9, 5.1}
# 5
# 7

# %%
# Set the style of seaborn
sns.set(style="whitegrid")

# Create a scatter plot with larger points
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PetalWidthCm', y='PetalLengthCm', hue='Species', data=iris, size=120, legend=False)

# Set custom X-axis and Y-axis limits
plt.xlim(0.9, 3.0)  # Example X-axis limits
plt.ylim(2.5, 7)      # Example Y-axis limits

x_ticks = np.arange(0.9, 3.0, 0.1)  # X-axis ticks from 1.5 to 4.5 with a step size of 0.5
y_ticks = np.arange(2.5, 7, 0.2)       # Y-axis ticks from 3 to 9 with a step size of 1
plt.xticks(x_ticks)
plt.yticks(y_ticks)
# Add labels and title
plt.xlabel('PetalWidthCm (cm)')
plt.ylabel('SPetalLengthCm (cm)')
plt.title('Scatter Plot: Petal Width vs Petal Length with Larger Points')

# Show the plot
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# ### Model -preparation

# %%
le = LabelEncoder()
iris["Species"] = le.fit_transform(iris["Species"])
iris["Species"].value_counts()
# Out:
# Species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
X=iris.drop(['Species','Id','SepalLengthCm','SepalWidthCm','PetalWidthCm'],axis='columns')
print(X.head())
# Out:
#    PetalLengthCm
# 0            1.4
# 1            1.4
# 2            1.3
# 3            1.5
# 4            1.4

# %%
Y=iris["Species"]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30)
print("train data length:",len(X_train))
print("test data length:",len(X_test))
# Out:
# train data length: 105
# test data length: 45

# %%
dt_model = DecisionTreeClassifier(max_depth=4)
dt_model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
dt_model.score(X_train,Y_train)
# Out:
# 0.9619047619047619

# %%
dt_model.score(X_test,Y_test)
# Out:
# 0.9333333333333333

# %%
print(classification_report(Y_test, dt_model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       0.89      0.94      0.92        18
#            2       0.93      0.87      0.90        15
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.94      0.94        45
# weighted avg       0.93      0.93      0.93        45

# %%
print(confusion_matrix(Y_test,dt_model.predict(X_test)))
sns.heatmap(confusion_matrix(Y_test,dt_model.predict(X_test)), annot=True)
plt.show()
# Out:
# [[15  0  0]
#  [ 0 12  3]
#  [ 0  2 13]]
